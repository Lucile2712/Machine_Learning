# %% [markdown]
# # Lab 1 Evaluation

# %% [markdown]
# Names, Surnames, and Group : (to complete by 2 students)

# %%
 # Nguyen Y-Quynh (group A2)
 # Cossoul Lucile (group A2)

# %% [markdown]
# In the following, we consider the  (binarized) Compas dataset that we studied in the Lab

# %% [markdown]
# Q1: A decision tree configuration is a set of parameters that one can use to build decision trees. Propose 6 configurations that are likely to provide different topologies and caracteristics
# Build severals decision trees (different parameters) and visualize them

# %%
import csv
import numpy as np
from utils import load_from_csv
from sklearn import tree
from matplotlib import pyplot as plt # for a good visualization of the trees 

train_examples, train_labels, features, prediction = load_from_csv("./compass.csv")


#TREE1
print("\n\n\nTREE1")
clf = tree.DecisionTreeClassifier(splitter='random', max_depth=100, min_samples_leaf=10)
clf = clf.fit(train_examples, train_labels)
#splitter
print("splitter : ", clf.splitter)

#max_depth
print("max_depth :", clf.max_depth)

#min_samples_leaf
print("min_samples_leaf :", clf.min_samples_leaf)
text_representation = tree.export_text(clf, feature_names=features)
print(text_representation)

fig = plt.figure(figsize=(10,7))
_ = tree.plot_tree(clf, 
                    feature_names= (features),
                    class_names= (prediction), 
                    filled=True)


#TREE2
print("\n\n\nTREE2")
clf = tree.DecisionTreeClassifier(splitter='random', max_depth=1, min_samples_leaf=10)
clf = clf.fit(train_examples, train_labels)
#splitter
print("splitter : ", clf.splitter)

#max_depth
print("max_depth :", clf.max_depth)

#min_samples_leaf
print("min_samples_leaf :", clf.min_samples_leaf)
text_representation = tree.export_text(clf, feature_names=features)
print(text_representation)

fig = plt.figure(figsize=(10,7))
_ = tree.plot_tree(clf, 
                    feature_names= (features),
                    class_names= (prediction), 
                    filled=True)



#TREE3
print("\n\n\nTREE3")
clf = tree.DecisionTreeClassifier(splitter='random', max_depth=10, min_samples_leaf=50)
clf = clf.fit(train_examples, train_labels)
#splitter
print("splitter : ", clf.splitter)

#max_depth
print("max_depth :", clf.max_depth)

#min_samples_leaf
print("min_samples_leaf :", clf.min_samples_leaf)
text_representation = tree.export_text(clf, feature_names=features)
print(text_representation)

fig = plt.figure(figsize=(10,7))
_ = tree.plot_tree(clf, 
                    feature_names= (features),
                    class_names= (prediction), 
                    filled=True)



#TREE4
print("\n\n\nTREE4")
clf = tree.DecisionTreeClassifier(splitter='best', max_depth=20, min_samples_leaf=10)
clf = clf.fit(train_examples, train_labels)
#splitter
print("splitter : ", clf.splitter)

#max_depth
print("max_depth :", clf.max_depth)

#min_samples_leaf
print("min_samples_leaf :", clf.min_samples_leaf)
text_representation = tree.export_text(clf, feature_names=features)
print(text_representation)

fig = plt.figure(figsize=(10,7))
_ = tree.plot_tree(clf, 
                    feature_names= (features),
                    class_names= (prediction), 
                    filled=True)


#TREE5
print("\n\n\nTREE5")
clf = tree.DecisionTreeClassifier(splitter='best', max_depth=50, min_samples_leaf=10)
clf = clf.fit(train_examples, train_labels)
#splitter
print("splitter : ", clf.splitter)

#max_depth
print("max_depth :", clf.max_depth)

#min_samples_leaf
print("min_samples_leaf :", clf.min_samples_leaf)
text_representation = tree.export_text(clf, feature_names=features)
print(text_representation)

fig = plt.figure(figsize=(10,7))
_ = tree.plot_tree(clf, 
                    feature_names= (features),
                    class_names= (prediction), 
                    filled=True)


#TREE6
print("\n\n\nTREE6")
clf = tree.DecisionTreeClassifier(splitter='best', max_depth=100, min_samples_leaf=50)
clf = clf.fit(train_examples, train_labels)
#splitter
print("splitter : ", clf.splitter)

#max_depth
print("max_depth :", clf.max_depth)

#min_samples_leaf
print("min_samples_leaf :", clf.min_samples_leaf)
text_representation = tree.export_text(clf, feature_names=features)
print(text_representation)

fig = plt.figure(figsize=(10,7))
_ = tree.plot_tree(clf, 
                    feature_names= (features),
                    class_names= (prediction), 
                    filled=True)
# Out:
# TREE1
# splitter :  random
# max_depth : 100
# min_samples_leaf : 10
# |--- not_priors_>3 <= 0.40
# |   |--- age_>45__AND__juvenile-crimes_=0 <= 1.00
# |   |   |--- age_26-45__AND__juvenile-crimes_=0 <= 0.71
# |   |   |   |--- juvenile-misdemeanors_=0__AND__gender_Female <= 0.78
# |   |   |   |   |--- race_African-American <= 0.33
# |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-misdemeanors_>0 <= 0.17
# |   |   |   |   |   |   |--- not_age_23-25 <= 0.17
# |   |   |   |   |   |   |   |--- gender_Male__AND__charge_degree_Misdemeanor <= 0.83
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- gender_Male__AND__charge_degree_Misdemeanor >  0.83
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- not_age_23-25 >  0.17
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-misdemeanors_>0 >  0.17
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- race_African-American >  0.33
# |   |   |   |   |   |--- juvenile-misdemeanors_>0__AND__charge_degree_Misdemeanor <= 0.83
# |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__juvenile-misdemeanors_>0 <= 0.91
# |   |   |   |   |   |   |   |--- juvenile-crimes_=0__AND__age_21-22 <= 0.60
# |   |   |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__charge_degree_Misdemeanor <= 0.59
# |   |   |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__age_26-45 <= 0.30
# |   |   |   |   |   |   |   |   |   |   |--- age_23-25__AND__charge_degree_Felony <= 0.71
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- age_23-25__AND__charge_degree_Felony >  0.71
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__age_26-45 >  0.30
# |   |   |   |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-felonies_=0 <= 0.87
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-felonies_=0 >  0.87
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__charge_degree_Misdemeanor >  0.59
# |   |   |   |   |   |   |   |   |   |--- age_23-25__AND__juvenile-felonies_=0 <= 0.92
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- age_23-25__AND__juvenile-felonies_=0 >  0.92
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- juvenile-crimes_=0__AND__age_21-22 >  0.60
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__juvenile-misdemeanors_>0 >  0.91
# |   |   |   |   |   |   |   |--- age_23-25__AND__juvenile-crimes_=0 <= 0.46
# |   |   |   |   |   |   |   |   |--- gender_Male__AND__age_26-45 <= 0.69
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- gender_Male__AND__age_26-45 >  0.69
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- age_23-25__AND__juvenile-crimes_=0 >  0.46
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- juvenile-misdemeanors_>0__AND__charge_degree_Misdemeanor >  0.83
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- juvenile-misdemeanors_=0__AND__gender_Female >  0.78
# |   |   |   |   |--- age_23-25__AND__juvenile-crimes_=0 <= 0.40
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- age_23-25__AND__juvenile-crimes_=0 >  0.40
# |   |   |   |   |   |--- class: 1
# |   |   |--- age_26-45__AND__juvenile-crimes_=0 >  0.71
# |   |   |   |--- gender_Male__AND__charge_degree_Felony <= 0.50
# |   |   |   |   |--- race_African-American <= 0.39
# |   |   |   |   |   |--- not_charge_degree_Felony <= 0.34
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- not_charge_degree_Felony >  0.34
# |   |   |   |   |   |   |--- gender_Male__AND__juvenile-felonies_=0 <= 0.92
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- gender_Male__AND__juvenile-felonies_=0 >  0.92
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- race_African-American >  0.39
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Misdemeanor <= 0.22
# |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__gender_Female <= 0.43
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__gender_Female >  0.43
# |   |   |   |   |   |   |   |--- age_26-45__AND__juvenile-misdemeanors_>0 <= 0.13
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- age_26-45__AND__juvenile-misdemeanors_>0 >  0.13
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Misdemeanor >  0.22
# |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__juvenile-felonies_=0 <= 0.86
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__juvenile-felonies_=0 >  0.86
# |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-misdemeanors_=0 <= 0.93
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-misdemeanors_=0 >  0.93
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- gender_Male__AND__charge_degree_Felony >  0.50
# |   |   |   |   |--- race_Caucasian <= 0.79
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__juvenile-felonies_>0 <= 0.69
# |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__juvenile-misdemeanors_>0 <= 0.26
# |   |   |   |   |   |   |   |--- not_juvenile-misdemeanors_>0 <= 0.67
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- not_juvenile-misdemeanors_>0 >  0.67
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__juvenile-misdemeanors_>0 >  0.26
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__juvenile-felonies_>0 >  0.69
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- race_Caucasian >  0.79
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__juvenile-felonies_=0 <= 0.37
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__juvenile-felonies_=0 >  0.37
# |   |   |   |   |   |   |--- class: 1
# |   |--- age_>45__AND__juvenile-crimes_=0 >  1.00
# |   |   |--- gender_Male__AND__charge_degree_Felony <= 0.41
# |   |   |   |--- race_Caucasian <= 0.90
# |   |   |   |   |--- priors_>3__AND__gender_Female <= 0.53
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- priors_>3__AND__gender_Female >  0.53
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- race_Caucasian >  0.90
# |   |   |   |   |--- gender_Female <= 0.17
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- gender_Female >  0.17
# |   |   |   |   |   |--- class: 1
# |   |   |--- gender_Male__AND__charge_degree_Felony >  0.41
# |   |   |   |--- race_Caucasian <= 0.37
# |   |   |   |   |--- class: 1
# |   |   |   |--- race_Caucasian >  0.37
# |   |   |   |   |--- class: 1
# |--- not_priors_>3 >  0.40
# |   |--- juvenile-crimes_=0__AND__priors_0 <= 0.09
# |   |   |--- age_>45__AND__juvenile-misdemeanors_=0 <= 0.03
# |   |   |   |--- age_26-45__AND__juvenile-felonies_=0 <= 0.57
# |   |   |   |   |--- age_23-25__AND__priors_1 <= 0.11
# |   |   |   |   |   |--- race_Caucasian <= 0.14
# |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__age_18-20 <= 0.69
# |   |   |   |   |   |   |   |--- priors_2-3__AND__gender_Male <= 0.01
# |   |   |   |   |   |   |   |   |--- age_21-22__AND__juvenile-crimes_>0 <= 0.31
# |   |   |   |   |   |   |   |   |   |--- age_21-22__AND__gender_Female <= 0.67
# |   |   |   |   |   |   |   |   |   |   |--- priors_2-3__AND__charge_degree_Felony <= 0.89
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- priors_2-3__AND__charge_degree_Felony >  0.89
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- age_21-22__AND__gender_Female >  0.67
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- age_21-22__AND__juvenile-crimes_>0 >  0.31
# |   |   |   |   |   |   |   |   |   |--- priors_1__AND__charge_degree_Felony <= 0.49
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- priors_1__AND__charge_degree_Felony >  0.49
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- priors_2-3__AND__gender_Male >  0.01
# |   |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 <= 0.10
# |   |   |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-misdemeanors_>0 <= 0.77
# |   |   |   |   |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__charge_degree_Felony <= 1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__charge_degree_Felony >  1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-misdemeanors_>0 >  0.77
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 >  0.10
# |   |   |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__age_21-22 <= 0.22
# |   |   |   |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-felonies_>0 <= 0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-felonies_>0 >  0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__age_21-22 >  0.22
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__age_18-20 >  0.69
# |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-misdemeanors_=0 <= 0.12
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-misdemeanors_=0 >  0.12
# |   |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 <= 0.10
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 >  0.10
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- race_Caucasian >  0.14
# |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-misdemeanors_>0 <= 0.28
# |   |   |   |   |   |   |   |--- priors_1__AND__age_21-22 <= 0.70
# |   |   |   |   |   |   |   |   |--- age_23-25__AND__juvenile-crimes_>0 <= 0.92
# |   |   |   |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__charge_degree_Misdemeanor <= 0.66
# |   |   |   |   |   |   |   |   |   |   |--- age_18-20__AND__charge_degree_Felony <= 0.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- age_18-20__AND__charge_degree_Felony >  0.84
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__charge_degree_Misdemeanor >  0.66
# |   |   |   |   |   |   |   |   |   |   |--- priors_2-3__AND__age_21-22 <= 0.39
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- priors_2-3__AND__age_21-22 >  0.39
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- age_23-25__AND__juvenile-crimes_>0 >  0.92
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- priors_1__AND__age_21-22 >  0.70
# |   |   |   |   |   |   |   |   |--- gender_Male__AND__charge_degree_Felony <= 0.88
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- gender_Male__AND__charge_degree_Felony >  0.88
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-misdemeanors_>0 >  0.28
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- age_23-25__AND__priors_1 >  0.11
# |   |   |   |   |   |--- charge_degree_Felony__AND__gender_Female <= 0.75
# |   |   |   |   |   |   |--- race_African-American <= 0.76
# |   |   |   |   |   |   |   |--- juvenile-crimes_=0__AND__charge_degree_Misdemeanor <= 0.25
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- juvenile-crimes_=0__AND__charge_degree_Misdemeanor >  0.25
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- race_African-American >  0.76
# |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__juvenile-crimes_>0 <= 0.52
# |   |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Felony <= 0.20
# |   |   |   |   |   |   |   |   |   |--- gender_Male__AND__charge_degree_Misdemeanor <= 0.52
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- gender_Male__AND__charge_degree_Misdemeanor >  0.52
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Felony >  0.20
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__juvenile-crimes_>0 >  0.52
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- charge_degree_Felony__AND__gender_Female >  0.75
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- age_26-45__AND__juvenile-felonies_=0 >  0.57
# |   |   |   |   |--- priors_2-3__AND__charge_degree_Felony <= 0.67
# |   |   |   |   |   |--- race_African-American <= 0.15
# |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 <= 0.04
# |   |   |   |   |   |   |   |--- priors_1__AND__charge_degree_Misdemeanor <= 0.17
# |   |   |   |   |   |   |   |   |--- priors_2-3__AND__gender_Male <= 0.17
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- priors_2-3__AND__gender_Male >  0.17
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- priors_1__AND__charge_degree_Misdemeanor >  0.17
# |   |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-misdemeanors_=0 <= 0.06
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-misdemeanors_=0 >  0.06
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 >  0.04
# |   |   |   |   |   |   |   |--- gender_Female <= 0.60
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- gender_Female >  0.60
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- race_African-American >  0.15
# |   |   |   |   |   |   |--- priors_1__AND__gender_Female <= 0.59
# |   |   |   |   |   |   |   |--- priors_2-3__AND__gender_Male <= 0.77
# |   |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__priors_1 <= 0.36
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__priors_1 >  0.36
# |   |   |   |   |   |   |   |   |   |--- juvenile-crimes_=0__AND__charge_degree_Misdemeanor <= 0.84
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- juvenile-crimes_=0__AND__charge_degree_Misdemeanor >  0.84
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- priors_2-3__AND__gender_Male >  0.77
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- priors_1__AND__gender_Female >  0.59
# |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Felony <= 0.58
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Felony >  0.58
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- priors_2-3__AND__charge_degree_Felony >  0.67
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__gender_Female <= 0.34
# |   |   |   |   |   |   |--- race_Caucasian <= 0.65
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- race_Caucasian >  0.65
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__gender_Female >  0.34
# |   |   |   |   |   |   |--- race_African-American <= 0.57
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- race_African-American >  0.57
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- age_>45__AND__juvenile-misdemeanors_=0 >  0.03
# |   |   |   |--- priors_2-3__AND__gender_Male <= 0.96
# |   |   |   |   |--- charge_degree_Misdemeanor__AND__gender_Female <= 0.09
# |   |   |   |   |   |--- priors_1__AND__gender_Female <= 0.29
# |   |   |   |   |   |   |--- priors_1__AND__charge_degree_Misdemeanor <= 0.18
# |   |   |   |   |   |   |   |--- race_African-American <= 0.60
# |   |   |   |   |   |   |   |   |--- priors_2-3__AND__age_>45 <= 0.30
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- priors_2-3__AND__age_>45 >  0.30
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- race_African-American >  0.60
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- priors_1__AND__charge_degree_Misdemeanor >  0.18
# |   |   |   |   |   |   |   |--- race_Caucasian <= 0.16
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- race_Caucasian >  0.16
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- priors_1__AND__gender_Female >  0.29
# |   |   |   |   |   |   |--- race_Caucasian <= 0.33
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- race_Caucasian >  0.33
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- charge_degree_Misdemeanor__AND__gender_Female >  0.09
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- priors_2-3__AND__gender_Male >  0.96
# |   |   |   |   |--- juvenile-crimes_=0__AND__charge_degree_Misdemeanor <= 0.59
# |   |   |   |   |   |--- race_African-American <= 0.69
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- race_African-American >  0.69
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- juvenile-crimes_=0__AND__charge_degree_Misdemeanor >  0.59
# |   |   |   |   |   |--- race_Caucasian <= 0.52
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- race_Caucasian >  0.52
# |   |   |   |   |   |   |--- class: 0
# |   |--- juvenile-crimes_=0__AND__priors_0 >  0.09
# |   |   |--- age_18-20__AND__priors_0 <= 0.46
# |   |   |   |--- gender_Male__AND__age_21-22 <= 0.52
# |   |   |   |   |--- age_>45__AND__juvenile-misdemeanors_=0 <= 0.54
# |   |   |   |   |   |--- charge_degree_Misdemeanor__AND__gender_Female <= 0.40
# |   |   |   |   |   |   |--- age_23-25__AND__charge_degree_Misdemeanor <= 0.88
# |   |   |   |   |   |   |   |--- age_21-22 <= 0.08
# |   |   |   |   |   |   |   |   |--- age_26-45__AND__charge_degree_Felony <= 0.46
# |   |   |   |   |   |   |   |   |   |--- race_Caucasian <= 0.05
# |   |   |   |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__gender_Female <= 0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__gender_Female >  0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- race_Caucasian >  0.05
# |   |   |   |   |   |   |   |   |   |   |--- not_gender_Male <= 0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- not_gender_Male >  0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- age_26-45__AND__charge_degree_Felony >  0.46
# |   |   |   |   |   |   |   |   |   |--- race_African-American <= 0.98
# |   |   |   |   |   |   |   |   |   |   |--- age_26-45__AND__gender_Female <= 0.61
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- age_26-45__AND__gender_Female >  0.61
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- race_African-American >  0.98
# |   |   |   |   |   |   |   |   |   |   |--- gender_Male__AND__priors_0 <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- gender_Male__AND__priors_0 >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- age_21-22 >  0.08
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age_23-25__AND__charge_degree_Misdemeanor >  0.88
# |   |   |   |   |   |   |   |--- race_African-American <= 0.47
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- race_African-American >  0.47
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- charge_degree_Misdemeanor__AND__gender_Female >  0.40
# |   |   |   |   |   |   |--- age_21-22__AND__gender_Female <= 0.71
# |   |   |   |   |   |   |   |--- age_23-25__AND__priors_0 <= 0.08
# |   |   |   |   |   |   |   |   |--- race_Caucasian <= 0.95
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- race_Caucasian >  0.95
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- age_23-25__AND__priors_0 >  0.08
# |   |   |   |   |   |   |   |   |--- race_African-American <= 0.75
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- race_African-American >  0.75
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age_21-22__AND__gender_Female >  0.71
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- age_>45__AND__juvenile-misdemeanors_=0 >  0.54
# |   |   |   |   |   |--- race_Caucasian <= 0.34
# |   |   |   |   |   |   |--- gender_Male__AND__juvenile-misdemeanors_=0 <= 0.86
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- gender_Male__AND__juvenile-misdemeanors_=0 >  0.86
# |   |   |   |   |   |   |   |--- age_>45__AND__charge_degree_Misdemeanor <= 0.95
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- age_>45__AND__charge_degree_Misdemeanor >  0.95
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- race_Caucasian >  0.34
# |   |   |   |   |   |   |--- gender_Male__AND__charge_degree_Felony <= 0.88
# |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 <= 0.91
# |   |   |   |   |   |   |   |   |--- gender_Female <= 0.08
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- gender_Female >  0.08
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 >  0.91
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- gender_Male__AND__charge_degree_Felony >  0.88
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- gender_Male__AND__age_21-22 >  0.52
# |   |   |   |   |--- race_Caucasian <= 0.63
# |   |   |   |   |   |--- juvenile-felonies_=0__AND__charge_degree_Felony <= 0.41
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- juvenile-felonies_=0__AND__charge_degree_Felony >  0.41
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- race_Caucasian >  0.63
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Misdemeanor <= 0.96
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Misdemeanor >  0.96
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- age_18-20__AND__priors_0 >  0.46
# |   |   |   |--- charge_degree_Felony__AND__gender_Female <= 0.59
# |   |   |   |   |--- juvenile-felonies_=0__AND__charge_degree_Misdemeanor <= 0.37
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- juvenile-felonies_=0__AND__charge_degree_Misdemeanor >  0.37
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- charge_degree_Felony__AND__gender_Female >  0.59
# |   |   |   |   |--- class: 0
#
#
#
#
# TREE2
# splitter :  random
# max_depth : 1
# min_samples_leaf : 10
# |--- priors_>3 <= 0.03
# |   |--- class: 0
# |--- priors_>3 >  0.03
# |   |--- class: 1
#
#
#
#
# TREE3
# splitter :  random
# max_depth : 10
# min_samples_leaf : 50
# |--- priors_>3 <= 0.72
# |   |--- juvenile-crimes_=0__AND__priors_0 <= 0.98
# |   |   |--- age_>45__AND__juvenile-misdemeanors_=0 <= 0.33
# |   |   |   |--- age_26-45__AND__juvenile-felonies_=0 <= 0.04
# |   |   |   |   |--- age_23-25__AND__priors_1 <= 0.95
# |   |   |   |   |   |--- race_Caucasian <= 0.17
# |   |   |   |   |   |   |--- age_18-20 <= 0.42
# |   |   |   |   |   |   |   |--- priors_2-3__AND__gender_Male <= 0.81
# |   |   |   |   |   |   |   |   |--- juvenile-crimes_=0__AND__age_21-22 <= 0.36
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- juvenile-crimes_=0__AND__age_21-22 >  0.36
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- priors_2-3__AND__gender_Male >  0.81
# |   |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 <= 0.88
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 >  0.88
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- age_18-20 >  0.42
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- race_Caucasian >  0.17
# |   |   |   |   |   |   |--- priors_2-3__AND__juvenile-felonies_=0 <= 0.69
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- priors_2-3__AND__juvenile-felonies_=0 >  0.69
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- age_23-25__AND__priors_1 >  0.95
# |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 <= 0.99
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 >  0.99
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- age_26-45__AND__juvenile-felonies_=0 >  0.04
# |   |   |   |   |--- priors_2-3__AND__charge_degree_Felony <= 0.38
# |   |   |   |   |   |--- race_Caucasian <= 0.49
# |   |   |   |   |   |   |--- priors_1__AND__gender_Female <= 0.13
# |   |   |   |   |   |   |   |--- priors_2-3__AND__gender_Male <= 0.01
# |   |   |   |   |   |   |   |   |--- priors_1__AND__charge_degree_Felony <= 0.73
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- priors_1__AND__charge_degree_Felony >  0.73
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- priors_2-3__AND__gender_Male >  0.01
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- priors_1__AND__gender_Female >  0.13
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- race_Caucasian >  0.49
# |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 <= 0.98
# |   |   |   |   |   |   |   |--- priors_1__AND__charge_degree_Misdemeanor <= 0.94
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- priors_1__AND__charge_degree_Misdemeanor >  0.94
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 >  0.98
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- priors_2-3__AND__charge_degree_Felony >  0.38
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__gender_Female <= 0.38
# |   |   |   |   |   |   |--- race_African-American <= 0.53
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- race_African-American >  0.53
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__gender_Female >  0.38
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- age_>45__AND__juvenile-misdemeanors_=0 >  0.33
# |   |   |   |--- priors_2-3__AND__gender_Male <= 0.75
# |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Misdemeanor <= 0.35
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Misdemeanor >  0.35
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- priors_2-3__AND__gender_Male >  0.75
# |   |   |   |   |--- juvenile-crimes_=0__AND__charge_degree_Misdemeanor <= 0.55
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- juvenile-crimes_=0__AND__charge_degree_Misdemeanor >  0.55
# |   |   |   |   |   |--- class: 0
# |   |--- juvenile-crimes_=0__AND__priors_0 >  0.98
# |   |   |--- not_age_18-20 <= 0.16
# |   |   |   |--- class: 1
# |   |   |--- not_age_18-20 >  0.16
# |   |   |   |--- gender_Male__AND__age_21-22 <= 0.45
# |   |   |   |   |--- age_>45__AND__juvenile-misdemeanors_=0 <= 0.20
# |   |   |   |   |   |--- charge_degree_Misdemeanor__AND__gender_Female <= 0.10
# |   |   |   |   |   |   |--- age_23-25__AND__charge_degree_Misdemeanor <= 0.11
# |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-misdemeanors_=0 <= 0.59
# |   |   |   |   |   |   |   |   |--- race_Caucasian <= 0.05
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- race_Caucasian >  0.05
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-misdemeanors_=0 >  0.59
# |   |   |   |   |   |   |   |   |--- age_26-45__AND__charge_degree_Felony <= 0.12
# |   |   |   |   |   |   |   |   |   |--- race_African-American <= 0.35
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- race_African-American >  0.35
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- age_26-45__AND__charge_degree_Felony >  0.12
# |   |   |   |   |   |   |   |   |   |--- race_African-American <= 0.08
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- race_African-American >  0.08
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age_23-25__AND__charge_degree_Misdemeanor >  0.11
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- charge_degree_Misdemeanor__AND__gender_Female >  0.10
# |   |   |   |   |   |   |--- race_African-American <= 0.85
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- race_African-American >  0.85
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- age_>45__AND__juvenile-misdemeanors_=0 >  0.20
# |   |   |   |   |   |--- race_Caucasian <= 0.04
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- race_Caucasian >  0.04
# |   |   |   |   |   |   |--- gender_Male__AND__charge_degree_Felony <= 0.44
# |   |   |   |   |   |   |   |--- charge_degree_Misdemeanor__AND__gender_Female <= 0.92
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- charge_degree_Misdemeanor__AND__gender_Female >  0.92
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- gender_Male__AND__charge_degree_Felony >  0.44
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- gender_Male__AND__age_21-22 >  0.45
# |   |   |   |   |--- class: 0
# |--- priors_>3 >  0.72
# |   |--- age_>45__AND__juvenile-crimes_=0 <= 0.69
# |   |   |--- age_26-45__AND__juvenile-crimes_=0 <= 0.36
# |   |   |   |--- gender_Male__AND__juvenile-crimes_>0 <= 0.50
# |   |   |   |   |--- gender_Male__AND__charge_degree_Felony <= 0.92
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- gender_Male__AND__charge_degree_Felony >  0.92
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- gender_Male__AND__juvenile-crimes_>0 >  0.50
# |   |   |   |   |--- charge_degree_Felony__AND__juvenile-misdemeanors_>0 <= 0.40
# |   |   |   |   |   |--- age_26-45__AND__juvenile-felonies_=0 <= 0.13
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- age_26-45__AND__juvenile-felonies_=0 >  0.13
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- charge_degree_Felony__AND__juvenile-misdemeanors_>0 >  0.40
# |   |   |   |   |   |--- class: 1
# |   |   |--- age_26-45__AND__juvenile-crimes_=0 >  0.36
# |   |   |   |--- gender_Male__AND__charge_degree_Felony <= 0.53
# |   |   |   |   |--- race_African-American <= 0.11
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- race_African-American >  0.11
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Misdemeanor <= 0.60
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Misdemeanor >  0.60
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- gender_Male__AND__charge_degree_Felony >  0.53
# |   |   |   |   |--- race_African-American <= 0.26
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- race_African-American >  0.26
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__juvenile-felonies_=0 <= 0.81
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__juvenile-felonies_=0 >  0.81
# |   |   |   |   |   |   |--- class: 1
# |   |--- age_>45__AND__juvenile-crimes_=0 >  0.69
# |   |   |--- gender_Male__AND__charge_degree_Felony <= 0.11
# |   |   |   |--- race_Caucasian <= 0.17
# |   |   |   |   |--- class: 0
# |   |   |   |--- race_Caucasian >  0.17
# |   |   |   |   |--- class: 0
# |   |   |--- gender_Male__AND__charge_degree_Felony >  0.11
# |   |   |   |--- race_African-American <= 0.62
# |   |   |   |   |--- class: 1
# |   |   |   |--- race_African-American >  0.62
# |   |   |   |   |--- class: 1
#
#
#
#
# TREE4
# splitter :  best
# max_depth : 20
# min_samples_leaf : 10
# |--- not_priors_>3 <= 0.50
# |   |--- age_>45__AND__juvenile-crimes_=0 <= 0.50
# |   |   |--- age_26-45__AND__juvenile-crimes_=0 <= 0.50
# |   |   |   |--- juvenile-misdemeanors_=0__AND__gender_Female <= 0.50
# |   |   |   |   |--- race_African-American <= 0.50
# |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-misdemeanors_>0 <= 0.50
# |   |   |   |   |   |   |--- not_age_23-25 <= 0.50
# |   |   |   |   |   |   |   |--- gender_Male__AND__charge_degree_Misdemeanor <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- gender_Male__AND__charge_degree_Misdemeanor >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- not_age_23-25 >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-misdemeanors_>0 >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- race_African-American >  0.50
# |   |   |   |   |   |--- juvenile-misdemeanors_>0__AND__charge_degree_Misdemeanor <= 0.50
# |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__juvenile-misdemeanors_>0 <= 0.50
# |   |   |   |   |   |   |   |--- juvenile-crimes_=0__AND__age_21-22 <= 0.50
# |   |   |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__charge_degree_Misdemeanor <= 0.50
# |   |   |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__age_26-45 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- age_23-25__AND__charge_degree_Felony <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- age_23-25__AND__charge_degree_Felony >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__age_26-45 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-felonies_=0 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-felonies_=0 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__charge_degree_Misdemeanor >  0.50
# |   |   |   |   |   |   |   |   |   |--- gender_Male__AND__age_23-25 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- gender_Male__AND__age_23-25 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- juvenile-crimes_=0__AND__age_21-22 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__juvenile-misdemeanors_>0 >  0.50
# |   |   |   |   |   |   |   |--- age_23-25__AND__juvenile-crimes_=0 <= 0.50
# |   |   |   |   |   |   |   |   |--- gender_Male__AND__age_26-45 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- gender_Male__AND__age_26-45 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- age_23-25__AND__juvenile-crimes_=0 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- juvenile-misdemeanors_>0__AND__charge_degree_Misdemeanor >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- juvenile-misdemeanors_=0__AND__gender_Female >  0.50
# |   |   |   |   |--- age_23-25__AND__juvenile-crimes_=0 <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- age_23-25__AND__juvenile-crimes_=0 >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |--- age_26-45__AND__juvenile-crimes_=0 >  0.50
# |   |   |   |--- gender_Male__AND__charge_degree_Felony <= 0.50
# |   |   |   |   |--- race_Caucasian <= 0.50
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Misdemeanor <= 0.50
# |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__gender_Female <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__gender_Female >  0.50
# |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Felony <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Felony >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Misdemeanor >  0.50
# |   |   |   |   |   |   |--- age_26-45__AND__juvenile-felonies_>0 <= 0.50
# |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-felonies_=0 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-felonies_=0 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- age_26-45__AND__juvenile-felonies_>0 >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- race_Caucasian >  0.50
# |   |   |   |   |   |--- juvenile-felonies_=0__AND__charge_degree_Felony <= 0.50
# |   |   |   |   |   |   |--- gender_Male__AND__juvenile-felonies_=0 <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- gender_Male__AND__juvenile-felonies_=0 >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- juvenile-felonies_=0__AND__charge_degree_Felony >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- gender_Male__AND__charge_degree_Felony >  0.50
# |   |   |   |   |--- race_Caucasian <= 0.50
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__juvenile-felonies_>0 <= 0.50
# |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__juvenile-misdemeanors_>0 <= 0.50
# |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__juvenile-crimes_=0 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__juvenile-crimes_=0 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__juvenile-misdemeanors_>0 >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__juvenile-felonies_>0 >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- race_Caucasian >  0.50
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__juvenile-felonies_=0 <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__juvenile-felonies_=0 >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |--- age_>45__AND__juvenile-crimes_=0 >  0.50
# |   |   |--- gender_Male__AND__charge_degree_Felony <= 0.50
# |   |   |   |--- race_African-American <= 0.50
# |   |   |   |   |--- not_gender_Female <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- not_gender_Female >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- race_African-American >  0.50
# |   |   |   |   |--- gender_Female <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- gender_Female >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |--- gender_Male__AND__charge_degree_Felony >  0.50
# |   |   |   |--- race_Caucasian <= 0.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- race_Caucasian >  0.50
# |   |   |   |   |--- class: 1
# |--- not_priors_>3 >  0.50
# |   |--- juvenile-crimes_=0__AND__priors_0 <= 0.50
# |   |   |--- age_>45__AND__juvenile-misdemeanors_=0 <= 0.50
# |   |   |   |--- age_26-45__AND__juvenile-felonies_=0 <= 0.50
# |   |   |   |   |--- age_23-25__AND__priors_1 <= 0.50
# |   |   |   |   |   |--- race_African-American <= 0.50
# |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-misdemeanors_>0 <= 0.50
# |   |   |   |   |   |   |   |--- priors_1__AND__age_21-22 <= 0.50
# |   |   |   |   |   |   |   |   |--- age_23-25__AND__juvenile-crimes_>0 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__charge_degree_Misdemeanor <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- age_18-20 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- age_18-20 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__charge_degree_Misdemeanor >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- priors_2-3__AND__age_21-22 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- priors_2-3__AND__age_21-22 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- age_23-25__AND__juvenile-crimes_>0 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- priors_1__AND__age_21-22 >  0.50
# |   |   |   |   |   |   |   |   |--- gender_Male__AND__charge_degree_Felony <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- gender_Male__AND__charge_degree_Felony >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-misdemeanors_>0 >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- race_African-American >  0.50
# |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__age_18-20 <= 0.50
# |   |   |   |   |   |   |   |--- priors_2-3__AND__gender_Male <= 0.50
# |   |   |   |   |   |   |   |   |--- age_21-22__AND__juvenile-crimes_>0 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- age_21-22__AND__gender_Female <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- priors_2-3__AND__charge_degree_Felony <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- priors_2-3__AND__charge_degree_Felony >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- age_21-22__AND__gender_Female >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- age_21-22__AND__juvenile-crimes_>0 >  0.50
# |   |   |   |   |   |   |   |   |   |--- priors_1__AND__charge_degree_Felony <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- priors_1__AND__charge_degree_Felony >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- priors_2-3__AND__gender_Male >  0.50
# |   |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- not_juvenile-misdemeanors_=0 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__charge_degree_Felony <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__charge_degree_Felony >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- not_juvenile-misdemeanors_=0 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 >  0.50
# |   |   |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__age_21-22 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__juvenile-crimes_=0 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__juvenile-crimes_=0 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__age_21-22 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- juvenile-felonies_=0__AND__age_18-20 >  0.50
# |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-misdemeanors_=0 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-misdemeanors_=0 >  0.50
# |   |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- age_23-25__AND__priors_1 >  0.50
# |   |   |   |   |   |--- charge_degree_Felony__AND__gender_Female <= 0.50
# |   |   |   |   |   |   |--- race_African-American <= 0.50
# |   |   |   |   |   |   |   |--- juvenile-crimes_=0__AND__charge_degree_Misdemeanor <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- juvenile-crimes_=0__AND__charge_degree_Misdemeanor >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- race_African-American >  0.50
# |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__juvenile-crimes_>0 <= 0.50
# |   |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Felony <= 0.50
# |   |   |   |   |   |   |   |   |   |--- gender_Male__AND__charge_degree_Misdemeanor <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- gender_Male__AND__charge_degree_Misdemeanor >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Felony >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__juvenile-crimes_>0 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- charge_degree_Felony__AND__gender_Female >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- age_26-45__AND__juvenile-felonies_=0 >  0.50
# |   |   |   |   |--- priors_2-3__AND__charge_degree_Felony <= 0.50
# |   |   |   |   |   |--- race_Caucasian <= 0.50
# |   |   |   |   |   |   |--- priors_1__AND__gender_Female <= 0.50
# |   |   |   |   |   |   |   |--- priors_2-3__AND__gender_Male <= 0.50
# |   |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__priors_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__priors_1 >  0.50
# |   |   |   |   |   |   |   |   |   |--- juvenile-crimes_=0__AND__charge_degree_Misdemeanor <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- juvenile-crimes_=0__AND__charge_degree_Misdemeanor >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- priors_2-3__AND__gender_Male >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- priors_1__AND__gender_Female >  0.50
# |   |   |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Felony <= 0.50
# ...
# |   |   |   |   |   |   |   |   |--- priors_2-3__AND__juvenile-felonies_=0 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- priors_2-3__AND__juvenile-felonies_=0 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- priors_1__AND__gender_Female >  0.50
# |   |   |   |   |   |   |--- race_Caucasian <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- race_Caucasian >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- charge_degree_Misdemeanor__AND__gender_Female >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- priors_2-3__AND__gender_Male >  0.50
# |   |   |   |   |--- juvenile-crimes_=0__AND__charge_degree_Misdemeanor <= 0.50
# |   |   |   |   |   |--- race_Caucasian <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- race_Caucasian >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- juvenile-crimes_=0__AND__charge_degree_Misdemeanor >  0.50
# |   |   |   |   |   |--- race_Caucasian <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- race_Caucasian >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |--- juvenile-crimes_=0__AND__priors_0 >  0.50
# |   |   |--- not_age_18-20 <= 0.50
# |   |   |   |--- charge_degree_Felony__AND__gender_Female <= 0.50
# |   |   |   |   |--- gender_Male__AND__charge_degree_Felony <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- gender_Male__AND__charge_degree_Felony >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- charge_degree_Felony__AND__gender_Female >  0.50
# |   |   |   |   |--- class: 0
# |   |   |--- not_age_18-20 >  0.50
# |   |   |   |--- gender_Male__AND__age_21-22 <= 0.50
# |   |   |   |   |--- age_>45__AND__juvenile-felonies_=0 <= 0.50
# |   |   |   |   |   |--- charge_degree_Misdemeanor__AND__gender_Female <= 0.50
# |   |   |   |   |   |   |--- age_23-25__AND__charge_degree_Misdemeanor <= 0.50
# |   |   |   |   |   |   |   |--- age_21-22__AND__gender_Female <= 0.50
# |   |   |   |   |   |   |   |   |--- age_26-45__AND__charge_degree_Felony <= 0.50
# |   |   |   |   |   |   |   |   |   |--- race_Caucasian <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- not_gender_Female <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- not_gender_Female >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- race_Caucasian >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- gender_Male__AND__priors_0 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- gender_Male__AND__priors_0 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- age_26-45__AND__charge_degree_Felony >  0.50
# |   |   |   |   |   |   |   |   |   |--- race_Caucasian <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-crimes_=0 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-crimes_=0 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- race_Caucasian >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__gender_Female <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__gender_Female >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- age_21-22__AND__gender_Female >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age_23-25__AND__charge_degree_Misdemeanor >  0.50
# |   |   |   |   |   |   |   |--- race_Caucasian <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- race_Caucasian >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- charge_degree_Misdemeanor__AND__gender_Female >  0.50
# |   |   |   |   |   |   |--- priors_0__AND__age_21-22 <= 0.50
# |   |   |   |   |   |   |   |--- not_age_26-45 <= 0.50
# |   |   |   |   |   |   |   |   |--- race_African-American <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- race_African-American >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- not_age_26-45 >  0.50
# |   |   |   |   |   |   |   |   |--- race_African-American <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- race_African-American >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- priors_0__AND__age_21-22 >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- age_>45__AND__juvenile-felonies_=0 >  0.50
# |   |   |   |   |   |--- race_Caucasian <= 0.50
# |   |   |   |   |   |   |--- age_>45__AND__gender_Female <= 0.50
# |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__priors_0 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__priors_0 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age_>45__AND__gender_Female >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- race_Caucasian >  0.50
# |   |   |   |   |   |   |--- gender_Male__AND__charge_degree_Felony <= 0.50
# |   |   |   |   |   |   |   |--- juvenile-crimes_=0__AND__charge_degree_Misdemeanor <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- juvenile-crimes_=0__AND__charge_degree_Misdemeanor >  0.50
# |   |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-felonies_=0 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- gender_Male__AND__juvenile-felonies_=0 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- gender_Male__AND__charge_degree_Felony >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- gender_Male__AND__age_21-22 >  0.50
# |   |   |   |   |--- race_African-American <= 0.50
# |   |   |   |   |   |--- juvenile-crimes_=0__AND__charge_degree_Misdemeanor <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- juvenile-crimes_=0__AND__charge_degree_Misdemeanor >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- race_African-American >  0.50
# |   |   |   |   |   |--- juvenile-felonies_=0__AND__charge_degree_Misdemeanor <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- juvenile-felonies_=0__AND__charge_degree_Misdemeanor >  0.50
# |   |   |   |   |   |   |--- class: 0
#
#
#
#
# TREE6
# splitter :  best
# max_depth : 100
# min_samples_leaf : 50
# |--- priors_>3 <= 0.50
# |   |--- juvenile-crimes_=0__AND__priors_0 <= 0.50
# |   |   |--- age_>45__AND__juvenile-felonies_=0 <= 0.50
# |   |   |   |--- age_26-45__AND__juvenile-felonies_=0 <= 0.50
# |   |   |   |   |--- age_23-25__AND__priors_1 <= 0.50
# |   |   |   |   |   |--- race_Caucasian <= 0.50
# |   |   |   |   |   |   |--- not_age_18-20 <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- not_age_18-20 >  0.50
# |   |   |   |   |   |   |   |--- priors_2-3__AND__gender_Male <= 0.50
# |   |   |   |   |   |   |   |   |--- juvenile-crimes_=0__AND__age_21-22 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- juvenile-crimes_=0__AND__age_21-22 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- priors_2-3__AND__gender_Male >  0.50
# |   |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- race_Caucasian >  0.50
# |   |   |   |   |   |   |--- priors_2-3__AND__juvenile-felonies_=0 <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- priors_2-3__AND__juvenile-felonies_=0 >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- age_23-25__AND__priors_1 >  0.50
# |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- age_26-45__AND__juvenile-felonies_=0 >  0.50
# |   |   |   |   |--- priors_2-3__AND__charge_degree_Felony <= 0.50
# |   |   |   |   |   |--- race_African-American <= 0.50
# |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 <= 0.50
# |   |   |   |   |   |   |   |--- priors_1__AND__charge_degree_Misdemeanor <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- priors_1__AND__charge_degree_Misdemeanor >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- charge_degree_Felony__AND__juvenile-crimes_=0 >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- race_African-American >  0.50
# |   |   |   |   |   |   |--- priors_1__AND__gender_Female <= 0.50
# |   |   |   |   |   |   |   |--- priors_2-3__AND__gender_Male <= 0.50
# |   |   |   |   |   |   |   |   |--- priors_1__AND__charge_degree_Felony <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- priors_1__AND__charge_degree_Felony >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- priors_2-3__AND__gender_Male >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- priors_1__AND__gender_Female >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- priors_2-3__AND__charge_degree_Felony >  0.50
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__gender_Female <= 0.50
# |   |   |   |   |   |   |--- race_Caucasian <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- race_Caucasian >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__gender_Female >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- age_>45__AND__juvenile-felonies_=0 >  0.50
# |   |   |   |--- priors_2-3__AND__gender_Male <= 0.50
# |   |   |   |   |--- charge_degree_Felony <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- charge_degree_Felony >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- priors_2-3__AND__gender_Male >  0.50
# |   |   |   |   |--- juvenile-crimes_=0__AND__charge_degree_Misdemeanor <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- juvenile-crimes_=0__AND__charge_degree_Misdemeanor >  0.50
# |   |   |   |   |   |--- class: 0
# |   |--- juvenile-crimes_=0__AND__priors_0 >  0.50
# |   |   |--- not_age_18-20 <= 0.50
# |   |   |   |--- class: 1
# |   |   |--- not_age_18-20 >  0.50
# |   |   |   |--- gender_Male__AND__age_21-22 <= 0.50
# |   |   |   |   |--- age_>45__AND__priors_0 <= 0.50
# |   |   |   |   |   |--- charge_degree_Misdemeanor__AND__gender_Female <= 0.50
# |   |   |   |   |   |   |--- age_23-25__AND__charge_degree_Misdemeanor <= 0.50
# |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__gender_Female <= 0.50
# |   |   |   |   |   |   |   |   |--- age_26-45__AND__charge_degree_Felony <= 0.50
# |   |   |   |   |   |   |   |   |   |--- race_Caucasian <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- age_26-45__AND__juvenile-felonies_=0 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- age_26-45__AND__juvenile-felonies_=0 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- race_Caucasian >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- age_26-45__AND__charge_degree_Felony >  0.50
# |   |   |   |   |   |   |   |   |   |--- race_African-American <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- race_African-American >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- charge_degree_Felony__AND__gender_Female >  0.50
# |   |   |   |   |   |   |   |   |--- race_Caucasian <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- race_Caucasian >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age_23-25__AND__charge_degree_Misdemeanor >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- charge_degree_Misdemeanor__AND__gender_Female >  0.50
# |   |   |   |   |   |   |--- race_Caucasian <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- race_Caucasian >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- age_>45__AND__priors_0 >  0.50
# |   |   |   |   |   |--- race_African-American <= 0.50
# |   |   |   |   |   |   |--- gender_Male__AND__charge_degree_Felony <= 0.50
# |   |   |   |   |   |   |   |--- charge_degree_Misdemeanor__AND__gender_Female <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- charge_degree_Misdemeanor__AND__gender_Female >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- gender_Male__AND__charge_degree_Felony >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- race_African-American >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- gender_Male__AND__age_21-22 >  0.50
# |   |   |   |   |--- class: 0
# |--- priors_>3 >  0.50
# |   |--- age_>45__AND__juvenile-crimes_=0 <= 0.50
# |   |   |--- age_26-45__AND__juvenile-crimes_=0 <= 0.50
# |   |   |   |--- gender_Male__AND__juvenile-crimes_>0 <= 0.50
# |   |   |   |   |--- gender_Male__AND__charge_degree_Felony <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- gender_Male__AND__charge_degree_Felony >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- gender_Male__AND__juvenile-crimes_>0 >  0.50
# |   |   |   |   |--- charge_degree_Felony__AND__juvenile-misdemeanors_>0 <= 0.50
# |   |   |   |   |   |--- age_26-45__AND__juvenile-felonies_=0 <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- age_26-45__AND__juvenile-felonies_=0 >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- charge_degree_Felony__AND__juvenile-misdemeanors_>0 >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |--- age_26-45__AND__juvenile-crimes_=0 >  0.50
# |   |   |   |--- gender_Male__AND__charge_degree_Felony <= 0.50
# |   |   |   |   |--- race_African-American <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- race_African-American >  0.50
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Misdemeanor <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__charge_degree_Misdemeanor >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- gender_Male__AND__charge_degree_Felony >  0.50
# |   |   |   |   |--- race_Caucasian <= 0.50
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__juvenile-felonies_=0 <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- juvenile-misdemeanors_=0__AND__juvenile-felonies_=0 >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- race_Caucasian >  0.50
# |   |   |   |   |   |--- class: 1
# |   |--- age_>45__AND__juvenile-crimes_=0 >  0.50
# |   |   |--- gender_Male__AND__charge_degree_Felony <= 0.50
# |   |   |   |--- race_African-American <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- race_African-American >  0.50
# |   |   |   |   |--- class: 0
# |   |   |--- gender_Male__AND__charge_degree_Felony >  0.50
# |   |   |   |--- race_African-American <= 0.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- race_African-American >  0.50
# |   |   |   |   |--- class: 1

# %% [markdown]
# <div style="border: 1px solid green; padding: 10px; margin-top: 10px; border-radius: 5px">
# Answer :
#
# We chose to make half of the trees using the best splitter and the other half using random splitter.
# This allows us to have very different trees.
# The ones made using the best splitter will always try to optimize the split while the random one allows to have a completely different tree every time and to test different options.
#
#
# In those tree, we fluctuated the max depth from 1 to 100. With a max depth of 1, the tree were definitely not very representative. However, if the depth was too big, the tree were overfitting and each end of a tree represented basically one person/example which is not helpful to predict new cases.
#
# We also changed the min_samples_leaf that allow us to make a more or less precise tree by defining how many samples on each side are needed at least when splitting off a node.</div>

# %% [markdown]
# Q2: Train a decision tree for each of the previous configurations on the full dataset
# Run a solid evaluation on different trees (with different parameters) by randomly splitting the data 80% for training and 20% for test *multiple times*.

# %%
import csv
import numpy as np
from utils import load_from_csv
from sklearn import tree
from matplotlib import pyplot as plt # for a good visualization of the trees 
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import numpy as np

datas_examples, datas_labels, features, prediction = load_from_csv("./compass.csv")

trees_errors = []

# train test split 5 times
for i in range(5):
    # Split dataset into 80% training and 20% test set
    train_examples, test_examples, train_labels, test_labels = train_test_split(datas_examples, datas_labels, random_state=None, test_size=0.20)
    
    one_tree_errors = []

    trees = [
        DecisionTreeClassifier(splitter='random', max_depth=100, min_samples_leaf=10),
        DecisionTreeClassifier(splitter='random', max_depth=1, min_samples_leaf=10),
        DecisionTreeClassifier(splitter='random', max_depth=10, min_samples_leaf=50),
        DecisionTreeClassifier(splitter='best', max_depth=20, min_samples_leaf=10),
        DecisionTreeClassifier(splitter='best', max_depth=50, min_samples_leaf=10),
        DecisionTreeClassifier(splitter='best', max_depth=100, min_samples_leaf=50)
    ]

    # train and test every tree 
    for tree in trees:
        tree.fit(train_examples, train_labels)
        test_results = tree.predict(test_examples)
        error = np.sum(test_results != test_labels) / len(test_results)
        one_tree_errors.append(error)
    
    trees_errors.append(one_tree_errors)

for i, split_errors in enumerate(trees_errors):
    print(f"\n\nOne train-test separation errors:")
    for j, error in enumerate(split_errors):
        print(f"TREE{j+1}: {error}")
# Out:
# One train-test separation errors:
# TREE1: 0.3412322274881517
# TREE2: 0.3687203791469194
# TREE3: 0.33744075829383885
# TREE4: 0.34218009478672984
# TREE5: 0.34218009478672984
# TREE6: 0.33744075829383885
#
#
# One train-test separation errors:
# TREE1: 0.33270142180094786
# TREE2: 0.36113744075829385
# TREE3: 0.32606635071090045
# TREE4: 0.33175355450236965
# TREE5: 0.33175355450236965
# TREE6: 0.32606635071090045
#
#
# One train-test separation errors:
# TREE1: 0.33838862559241706
# TREE2: 0.3819905213270142
# TREE3: 0.3355450236966825
# TREE4: 0.33838862559241706
# TREE5: 0.33838862559241706
# TREE6: 0.33270142180094786
#
#
# One train-test separation errors:
# TREE1: 0.3289099526066351
# TREE2: 0.35734597156398107
# TREE3: 0.3175355450236967
# TREE4: 0.3289099526066351
# TREE5: 0.3289099526066351
# TREE6: 0.3175355450236967
#
#
# One train-test separation errors:
# TREE1: 0.3412322274881517
# TREE2: 0.3582938388625592
# TREE3: 0.32796208530805687
# TREE4: 0.3412322274881517
# TREE5: 0.3412322274881517
# TREE6: 0.32796208530805687

# %% [markdown]
# <div style="border: 1px solid green; padding: 10px; margin-top: 10px; border-radius: 5px">
# Answer :
#
# We changed the training and testing examples every time for each tree. We notice the rate of errors varies but stays around the 33% range.
# We notice that using the "best" splitter we have consistently better results than using the random one.
# When the max depth is 1, we get a lot of mistakes. It makes sense since the tree is severely underfit.
#
# </div>

# %% [markdown]
# Q3: Propose an evaluation in terms of training and testing accuracies using $5$-cross validation on two decision trees that have different topologies
# Do again the evaluation using 5-cross-validation

# %%
import csv
import numpy as np
from utils import load_from_csv
from sklearn import tree
from matplotlib import pyplot as plt 
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report


datas_examples, datas_labels, features, prediction = load_from_csv("./compass.csv")

#split 80% train and 20% test     
train_examples = datas_examples[:int(0.8*len(datas_examples))]
test_examples = datas_examples[int(0.8*len(datas_examples)):]
train_labels = datas_labels[:int(0.8*len(datas_labels))]
test_labels = datas_labels[int(0.8*len(datas_labels)):]

#5 cross validation


#TREE1
clf = tree.DecisionTreeClassifier(splitter='random', max_depth=100, min_samples_leaf=10)

scores = cross_val_score(clf, datas_examples, datas_labels, cv=5)
print('scores :', scores)
mean_accuracy = scores.mean()
print('Mean accuracy : %.2f' % mean_accuracy)

#Train on all data
clf.fit(train_examples, train_labels)

#Predict labels for the test set
prediction = clf.predict(test_examples)

print(classification_report(test_labels, prediction))

#Plotting the decision tree
#plt.figure(figsize=(15,10))
#tree.plot_tree(clf, filled=True)
#plt.show()


#TREE6
clf = tree.DecisionTreeClassifier(splitter='best', max_depth=100, min_samples_leaf=50)

scores = cross_val_score(clf, datas_examples, datas_labels, cv=5)
print('scores :', scores)
mean_accuracy = scores.mean()
print('Mean accuracy : %.2f' % mean_accuracy)

#Train on all data
clf.fit(train_examples, train_labels)

#Predict labels for the test set
prediction = clf.predict(test_examples)

print(classification_report(test_labels, prediction))

#Plotting the decision tree
#plt.figure(figsize=(15,10))
#tree.plot_tree(clf, filled=True)
#plt.show()
# Out:
# scores : [0.65687204 0.66635071 0.66729858 0.66603416 0.64136622]
# Mean accuracy : 0.66
#               precision    recall  f1-score   support
#
#            0       0.64      0.72      0.68       559
#            1       0.64      0.55      0.59       496
#
#     accuracy                           0.64      1055
#    macro avg       0.64      0.64      0.64      1055
# weighted avg       0.64      0.64      0.64      1055
#
# scores : [0.67014218 0.65308057 0.66919431 0.67267552 0.66603416]
# Mean accuracy : 0.67
#               precision    recall  f1-score   support
#
#            0       0.68      0.69      0.69       559
#            1       0.65      0.64      0.64       496
#
#     accuracy                           0.67      1055
#    macro avg       0.67      0.66      0.66      1055
# weighted avg       0.67      0.67      0.67      1055

# %% [markdown]
# <div style="border: 1px solid green; padding: 10px; margin-top: 10px; border-radius: 5px">
# Answer : For those 2 configurations, the 5 cross-validation training is used to split data in 5 folds and trained the model on 4 folds, then 1 for testing.
#
# This procedure is repeated 5 times.
#
# This cross validation allows us to have an estimation of the model accuracy that is around 0.66 and 0.67. In our case, the accuracy of the model is rather low.
# </div>

# %% [markdown]
# Q4: Propose an experimental study that shows the transition phase from underfitting to overfitting
# Evaluate the impact (in terms of accuracy) of the three parameters : maximum depth, splitting criterion, and the minimum sample leafs.

# %%
train_examples, train_labels, features, prediction = load_from_csv("./compass.csv")


#Tests to visualise underfitting and overfitting

for i in range(1,10):
    clf = tree.DecisionTreeClassifier(splitter='best', max_depth=i*2)

    scores = cross_val_score(clf, datas_examples, datas_labels, cv=5)
    print('scores for max depth:', i*2, " is ", scores)
    mean_accuracy = scores.mean()
    print('Mean accuracy: %.2f' % mean_accuracy)
    clf.fit(train_examples, train_labels)
    prediction = clf.predict(test_examples)
    #print the error of the prediction
    nb_error = np.sum(prediction != test_labels)/len(prediction)
    print('error: ', nb_error)

for i in range(1,25):
    clf = tree.DecisionTreeClassifier(splitter='best', min_samples_leaf=i*10)

    scores = cross_val_score(clf, datas_examples, datas_labels, cv=5)
    print('scores for min samples leaf:', i*10, " is ", scores)
    mean_accuracy = scores.mean()
    print('Mean accuracy: %.2f' % mean_accuracy)
    clf.fit(train_examples, train_labels)
    prediction = clf.predict(test_examples)
    #print the error of the prediction
    nb_error = np.sum(prediction != test_labels)/len(prediction)
    print('error: ', nb_error)
# Out:
# scores for max depth: 2  is  [0.62938389 0.63507109 0.62938389 0.64326376 0.61385199]
# Mean accuracy: 0.63
# error:  0.3696682464454976
# scores for max depth: 4  is  [0.67298578 0.6521327  0.66255924 0.67552182 0.64516129]
# Mean accuracy: 0.66
# error:  0.3355450236966825
# scores for max depth: 6  is  [0.65687204 0.65687204 0.65592417 0.65749526 0.64895636]
# Mean accuracy: 0.66
# error:  0.33649289099526064
# scores for max depth: 8  is  [0.6549763  0.6492891  0.65781991 0.66888046 0.64895636]
# Mean accuracy: 0.66
# error:  0.31563981042654027
# scores for max depth: 10  is  [0.6549763  0.65971564 0.6521327  0.65939279 0.63472486]
# Mean accuracy: 0.65
# error:  0.31469194312796206
# scores for max depth: 12  is  [0.6521327  0.65687204 0.64739336 0.65654649 0.62998102]
# Mean accuracy: 0.65
# error:  0.31469194312796206
# scores for max depth: 14  is  [0.6521327  0.65876777 0.6492891  0.65370019 0.63092979]
# Mean accuracy: 0.65
# error:  0.3109004739336493
# scores for max depth: 16  is  [0.65118483 0.65781991 0.6492891  0.65085389 0.62998102]
# Mean accuracy: 0.65
# error:  0.3109004739336493
# scores for max depth: 18  is  [0.65023697 0.65592417 0.64834123 0.64990512 0.62808349]
# Mean accuracy: 0.65
# error:  0.3109004739336493
# scores for min samples leaf: 10  is  [0.65687204 0.66635071 0.66729858 0.66603416 0.64136622]
# Mean accuracy: 0.66
# error:  0.3127962085308057
# scores for min samples leaf: 20  is  [0.6549763  0.66161137 0.67109005 0.67362429 0.66129032]
# Mean accuracy: 0.66
# error:  0.31563981042654027
# scores for min samples leaf: 30  is  [0.66066351 0.66445498 0.67203791 0.67457306 0.65844402]
# Mean accuracy: 0.67
# error:  0.32132701421800947
# scores for min samples leaf: 40  is  [0.66824645 0.65971564 0.66919431 0.67552182 0.66223909]
# Mean accuracy: 0.67
# error:  0.3298578199052133
# scores for min samples leaf: 50  is  [0.67014218 0.65308057 0.66919431 0.67267552 0.66603416]
# Mean accuracy: 0.67
# error:  0.3298578199052133
# scores for min samples leaf: 60  is  [0.65876777 0.65781991 0.67014218 0.66223909 0.66034156]
# Mean accuracy: 0.66
# error:  0.3298578199052133
# scores for min samples leaf: 70  is  [0.65876777 0.64549763 0.67298578 0.67267552 0.65085389]
# Mean accuracy: 0.66
# error:  0.3298578199052133
# scores for min samples leaf: 80  is  [0.65592417 0.65402844 0.67488152 0.67267552 0.65464896]
# Mean accuracy: 0.66
# error:  0.33080568720379144
# scores for min samples leaf: 90  is  [0.6492891  0.65402844 0.67488152 0.67267552 0.65464896]
# Mean accuracy: 0.66
# error:  0.3355450236966825
# scores for min samples leaf: 100  is  [0.6436019  0.65402844 0.67488152 0.67267552 0.65464896]
# Mean accuracy: 0.66
# error:  0.33933649289099527
# scores for min samples leaf: 110  is  [0.6436019  0.65118483 0.65781991 0.66413662 0.64231499]
# Mean accuracy: 0.65
# error:  0.33933649289099527
# scores for min samples leaf: 120  is  [0.65118483 0.65118483 0.65781991 0.66318786 0.64326376]
# Mean accuracy: 0.65
# error:  0.33933649289099527
# scores for min samples leaf: 130  is  [0.65118483 0.65118483 0.65781991 0.66318786 0.64421252]
# Mean accuracy: 0.65
# error:  0.33744075829383885
# scores for min samples leaf: 140  is  [0.65118483 0.65118483 0.65781991 0.66318786 0.64705882]
# Mean accuracy: 0.65
# error:  0.33744075829383885
# scores for min samples leaf: 150  is  [0.6492891  0.64834123 0.65781991 0.66318786 0.64705882]
# Mean accuracy: 0.65
# error:  0.34407582938388626
# scores for min samples leaf: 160  is  [0.6492891  0.63981043 0.65781991 0.66318786 0.63662239]
# Mean accuracy: 0.65
# error:  0.3459715639810427
# scores for min samples leaf: 170  is  [0.66255924 0.63412322 0.65781991 0.66318786 0.63662239]
# Mean accuracy: 0.65
# error:  0.3459715639810427
# scores for min samples leaf: 180  is  [0.66255924 0.63412322 0.65781991 0.66318786 0.63377609]
# Mean accuracy: 0.65
# error:  0.3459715639810427
# scores for min samples leaf: 190  is  [0.66255924 0.63601896 0.65781991 0.66318786 0.64326376]
# Mean accuracy: 0.65
# error:  0.3459715639810427
# scores for min samples leaf: 200  is  [0.66255924 0.63601896 0.65781991 0.66318786 0.64326376]
# Mean accuracy: 0.65
# error:  0.33933649289099527
# scores for min samples leaf: 210  is  [0.66255924 0.64739336 0.65781991 0.66318786 0.64326376]
# Mean accuracy: 0.65
# error:  0.33933649289099527
# scores for min samples leaf: 220  is  [0.66255924 0.63507109 0.65781991 0.66318786 0.64326376]
# Mean accuracy: 0.65
# error:  0.33933649289099527
# scores for min samples leaf: 230  is  [0.66255924 0.63507109 0.65781991 0.66318786 0.64326376]
# Mean accuracy: 0.65
# error:  0.33933649289099527
# scores for min samples leaf: 240  is  [0.66255924 0.63507109 0.65781991 0.66318786 0.64326376]
# Mean accuracy: 0.65
# error:  0.33933649289099527

# %% [markdown]
# <div style="border: 1px solid green; padding: 10px; margin-top: 10px; border-radius: 5px">
# Answer :
# On this model, maximum depth, splitting criterion, and the minimum sample leafs have a really low impacts on the results. The accuracy is always between 0.63 and 0.67.
# The parameter that had the most impact was the min_samples_leaf. Changing the splitter from 'random' to 'best' upgraded the global accuracy by 0.1.
#
#
#
#
#
# The most underfitting one is with max_depth 2, min_samples_leaf None, accuracy 0.63,
# The most overfitting one is with max_depth >8, min_samples_leaf >100, accuracy 0.65
# </div>

# %% [markdown]
# Q5: Construct the confusion matrix on a particular good configuration (after explaining your choice)
# Study the confusion matrix to evaluate the True/False Positive/Negative Rate. What are the most important parameters?

# %%
from sklearn.metrics import confusion_matrix

datas_examples, datas_labels, features, prediction = load_from_csv("./compass.csv")
#split 80% train and 20% test
train_examples = datas_examples[:int(0.8*len(datas_examples))]
test_examples = datas_examples[int(0.8*len(datas_examples)):]
train_labels = datas_labels[:int(0.8*len(datas_labels))]
test_labels = datas_labels[int(0.8*len(datas_labels)):]

#best model
clf = tree.DecisionTreeClassifier(splitter='best', min_samples_leaf=30)
clf = clf.fit(train_examples, train_labels)

predictions = clf.predict(test_examples)
conf_matrix = confusion_matrix(test_labels, predictions)

print(conf_matrix)
print(features)
# Out:
# [[385 174]
#  [186 310]]
# ['race_African-American', 'race_Caucasian', 'gender_Female', 'gender_Male', 'age_18-20', 'age_21-22', 'age_23-25', 'age_26-45', 'age_>45', 'juvenile-felonies_=0', 'juvenile-felonies_>0', 'juvenile-misdemeanors_=0', 'juvenile-misdemeanors_>0', 'juvenile-crimes_=0', 'juvenile-crimes_>0', 'priors_0', 'priors_1', 'priors_2-3', 'priors_>3', 'charge_degree_Misdemeanor', 'charge_degree_Felony', 'not_gender_Female', 'not_gender_Male', 'not_age_18-20', 'not_age_21-22', 'not_age_23-25', 'not_age_26-45', 'not_age_>45', 'not_juvenile-felonies_=0', 'not_juvenile-felonies_>0', 'not_juvenile-misdemeanors_=0', 'not_juvenile-misdemeanors_>0', 'not_juvenile-crimes_=0', 'not_juvenile-crimes_>0', 'not_priors_0', 'not_priors_1', 'not_priors_2-3', 'not_priors_>3', 'not_charge_degree_Misdemeanor', 'not_charge_degree_Felony', 'juvenile-misdemeanors_=0__AND__juvenile-felonies_=0', 'gender_Male__AND__juvenile-felonies_=0', 'gender_Male__AND__juvenile-misdemeanors_=0', 'gender_Male__AND__juvenile-crimes_=0', 'juvenile-felonies_=0__AND__charge_degree_Felony', 'juvenile-misdemeanors_=0__AND__charge_degree_Felony', 'gender_Male__AND__charge_degree_Felony', 'charge_degree_Felony__AND__juvenile-crimes_=0', 'juvenile-felonies_=0__AND__priors_0', 'juvenile-misdemeanors_=0__AND__priors_0', 'gender_Male__AND__priors_0', 'charge_degree_Felony__AND__priors_0', 'juvenile-crimes_=0__AND__priors_0', 'age_26-45__AND__priors_0', 'priors_0__AND__charge_degree_Misdemeanor', 'juvenile-felonies_=0__AND__age_21-22', 'juvenile-misdemeanors_=0__AND__age_21-22', 'gender_Male__AND__age_21-22', 'charge_degree_Felony__AND__age_21-22', 'priors_0__AND__age_21-22', 'juvenile-crimes_=0__AND__age_21-22', 'age_21-22__AND__charge_degree_Misdemeanor', 'priors_2-3__AND__age_21-22', 'age_21-22__AND__gender_Female', 'priors_1__AND__age_21-22', 'gender_Male__AND__juvenile-crimes_>0', 'juvenile-felonies_=0__AND__juvenile-crimes_>0', 'juvenile-misdemeanors_=0__AND__juvenile-crimes_>0', 'charge_degree_Felony__AND__juvenile-crimes_>0', 'age_21-22__AND__juvenile-crimes_>0', 'priors_0__AND__juvenile-crimes_>0', 'age_23-25__AND__juvenile-crimes_>0', 'priors_1__AND__juvenile-crimes_>0', 'priors_2-3__AND__juvenile-crimes_>0', 'priors_>3__AND__juvenile-crimes_>0', 'juvenile-crimes_>0__AND__charge_degree_Misdemeanor', 'age_26-45__AND__juvenile-crimes_>0', 'juvenile-felonies_=0__AND__juvenile-crimes_=0', 'juvenile-misdemeanors_=0__AND__juvenile-crimes_=0', 'age_26-45__AND__juvenile-felonies_=0', 'age_26-45__AND__juvenile-crimes_=0', 'juvenile-misdemeanors_=0__AND__age_26-45', 'age_26-45__AND__charge_degree_Felony', 'gender_Male__AND__age_26-45', 'priors_>3__AND__juvenile-felonies_=0', 'priors_>3__AND__juvenile-crimes_=0', 'priors_>3__AND__juvenile-misdemeanors_=0', 'priors_>3__AND__charge_degree_Felony', 'priors_>3__AND__age_26-45', 'priors_>3__AND__gender_Male', 'priors_>3__AND__charge_degree_Misdemeanor', 'juvenile-felonies_=0__AND__gender_Female', 'juvenile-misdemeanors_=0__AND__gender_Female', 'juvenile-crimes_=0__AND__gender_Female', 'charge_degree_Felony__AND__gender_Female', 'age_26-45__AND__gender_Female', 'priors_>3__AND__gender_Female', 'priors_0__AND__gender_Female', 'charge_degree_Misdemeanor__AND__gender_Female', 'gender_Male__AND__juvenile-misdemeanors_>0', 'juvenile-felonies_=0__AND__juvenile-misdemeanors_>0', 'charge_degree_Felony__AND__juvenile-misdemeanors_>0', 'priors_>3__AND__juvenile-misdemeanors_>0', 'juvenile-crimes_=0__AND__juvenile-misdemeanors_>0', 'age_26-45__AND__juvenile-misdemeanors_>0', 'age_23-25__AND__juvenile-misdemeanors_>0', 'priors_2-3__AND__juvenile-misdemeanors_>0', 'juvenile-misdemeanors_>0__AND__charge_degree_Misdemeanor', 'juvenile-misdemeanors_>0__AND__juvenile-crimes_>0', 'juvenile-misdemeanors_>0__AND__age_21-22', 'juvenile-felonies_=0__AND__charge_degree_Misdemeanor', 'juvenile-misdemeanors_=0__AND__charge_degree_Misdemeanor', 'juvenile-crimes_=0__AND__charge_degree_Misdemeanor', 'gender_Male__AND__charge_degree_Misdemeanor', 'age_26-45__AND__charge_degree_M ...

# %% [markdown]
# <div style="border: 1px solid green; padding: 10px; margin-top: 10px; border-radius: 5px">
# Answer : We chose our best configuration that was not underfitting or overfitting. It obtained the best score in the previous question with the cross_val_score function. It had the parameters splitter='best', min_samples_leaf=30 and max_depth = None by default.
#
# The most important parameters in the confusion matrix are False Positive and True Negative because it shows what were wrongly calculated in the model.
#
# For example, the False Positive Rate is calculated with : False Positive / (False Positive + True Negative)
# </div>

# %% [markdown]
# Q6: Provide an evaluation of the fairness of the model based on the False Positive Rate.
# Propose a way to assess whether the algorithm is fair to a particular ethnic group.

# %%
#evaluation of the fairness of the model (with False Positive Rate)
#False Positive Rate = FP / (FP + TN) 
def evaluate_fairness(conf_matrix):
    
    TN = conf_matrix[0,0]
    FP = conf_matrix[0,1]
    FN = conf_matrix[1,0]
    TP = conf_matrix[1,1]
    FPR = FP / (FP + TN)
    return FPR

filtered_examples_african_american = []
filtered_examples_caucasian= []

filtered_labels_african_american = []
filtered_labels_caucasian= []

for i in range(len(test_examples)):
    example = test_examples[i]
    label = test_labels[i]
    if example[0]==1:
        filtered_examples_african_american.append(example)
        filtered_labels_african_american.append(label)
    elif example[1]==1:
        filtered_examples_caucasian.append(example)
        filtered_labels_caucasian.append(label)

filtered_predictions_african_american=clf.predict(filtered_examples_african_american)
conf_matrix_african_american = confusion_matrix(filtered_labels_african_american, filtered_predictions_african_american)

filtered_predictions_caucasian=clf.predict(filtered_examples_caucasian)
conf_matrix_caucasian = confusion_matrix(filtered_labels_caucasian, filtered_predictions_caucasian)

print(conf_matrix_african_american)
print(conf_matrix_caucasian)

#for i in range(10): 
#    print("african american", filtered_predictions_african_american[i])
#    print("caucasian", filtered_predictions_caucasian[i])

#evaluate fairness for population1
print("African American :", evaluate_fairness(conf_matrix_african_american))
print("Caucasian :", evaluate_fairness(conf_matrix_caucasian))
# Out:
# [[181 119]
#  [112 230]]
# [[204  55]
#  [ 74  80]]
# African American : 0.39666666666666667
# Caucasian : 0.21235521235521235

# %% [markdown]
# <div style="border: 1px solid green; padding: 10px; margin-top: 10px; border-radius: 5px">
# Answer : We tested the fairness of the 2 ethnic groups: African American and Caucasian.
#
# After creating the confusion matrix for the both groups and calculating the false positive rate, we can see that African American group (40%) has two times more false positive than the Caucasian group (21%). This model shows that it is biased and not fair for all groups.
# </div>
